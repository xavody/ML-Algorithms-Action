# %%
import numpy as np
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
X = iris.data
y = iris.target

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (120,)
# (30, 4)
# (30,)

# %% [markdown]
# # scikit-learn中的StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
standardScaler = StandardScaler()

# %%
standardScaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
standardScaler.mean_
# Out:
# array([5.86      , 3.05166667, 3.84833333, 1.23833333])

# %%
standardScaler.scale_
# Out:
# array([0.82121861, 0.41912276, 1.72959453, 0.76203492])

# %%
X_train = standardScaler.transform(X_train)

# %%
X_train
# Out:
# array([[ 0.0487081 , -0.12327335,  0.72367636,  0.73706158],
#        [-0.56014318, -0.12327335,  0.37677424,  0.34337884],
#        [ 0.0487081 ,  0.35391381,  0.5502253 ,  0.73706158],
#        [-0.31660267, -0.12327335,  0.37677424,  0.34337884],
#        [-0.43837292, -1.79342841,  0.08768915,  0.08092368],
#        [ 0.77932964,  0.35391381,  0.72367636,  0.99951675],
#        [ 0.29224861, -0.36186693,  0.49240828,  0.21215126],
#        [-1.65607548, -1.79342841, -1.47337037, -1.23135214],
#        [ 0.17047836, -2.03202199,  0.08768915, -0.31275907],
#        [ 0.29224861, -0.60046051,  0.49240828, -0.05030391],
#        [-1.0472242 , -0.12327335, -1.29991932, -1.36257972],
#        [-0.92545395, -1.31624125, -0.49048105, -0.18153149],
#        [ 0.77932964, -0.12327335,  1.12839549,  1.26197191],
#        [ 1.02287015,  0.11532023,  1.01276145,  1.52442707],
#        [ 1.63172143,  1.30828813,  1.30184655,  1.65565466],
#        [ 0.41401887, -0.60046051,  0.5502253 ,  0.73706158],
#        [ 0.77932964, -0.12327335,  0.95494443,  0.73706158],
#        [ 0.17047836, -0.83905409,  0.72367636,  0.47460642],
#        [ 0.65755938,  0.35391381,  0.8393104 ,  1.39319949],
#        [ 1.02287015, -1.31624125,  1.12839549,  0.73706158],
#        [-0.07306215, -1.07764767,  0.08768915, -0.05030391],
#        [-1.16899446,  0.11532023, -1.35773634, -1.49380731],
#        [-0.92545395,  1.78547529, -1.12646826, -1.10012456],
#        [ 1.14464041,  0.35391381,  1.18621251,  1.39319949],
#        [-0.31660267, -1.31624125,  0.02987213, -0.18153149],
#        [ 1.02287015, -0.12327335,  0.66585934,  0.605834  ],
#        [ 2.24057271, -1.07764767,  1.7643827 ,  1.39319949],
#        [-1.0472242 ,  1.06969455, -1.29991932, -0.8376694 ],
#        [-0.19483241, -0.36186693,  0.20332318,  0.08092368],
#        [-0.80368369, -0.83905409,  0.02987213,  0.21215126],
#        [-0.92545395,  1.06969455, -1.41555336, -1.36257972],
#        [-1.29076471, -0.12327335, -1.41555336, -1.23135214],
#        [-0.92545395,  1.06969455, -1.41555336, -1.23135214],
#        [ 1.87526194, -0.60046051,  1.30184655,  0.86828917],
#        [ 0.17047836,  0.83110097,  0.37677424,  0.47460642],
#        [-0.43837292, -1.55483483, -0.02794489, -0.18153149],
#        [ 1.26641066,  0.35391381,  1.07057847,  1.39319949],
#        [ 0.29224861, -0.12327335,  0.43459126,  0.21215126],
#        [ 1.63172143,  0.35391381,  1.24402953,  0.73706158],
#        [-1.0472242 ,  1.30828813, -1.41555336, -1.36257972],
#        [-1.77784574, -0.36186693, -1.41555336, -1.36257972],
#        [-0.80368369,  0.83110097, -1.41555336, -1.36257972],
#        [ 0.17047836, -0.12327335,  0.5502253 ,  0.73706158],
#        [-1.89961599, -0.12327335, -1.58900441, -1.49380731],
#        [ 0.29224861, -1.07764767,  1.01276145,  0.21215126],
#        [ 0.53578913,  0.59250739,  1.24402953,  1.65565466],
#        [-0.19483241, -1.07764767, -0.20139595, -0.31275907],
#        [ 0.77932964, -0.60046051,  0.43459126,  0.34337884],
#        [ 2.24057271,  1.78547529,  1.64874867,  1.26197191],
#        [-0.80368369,  2.50125603, -1.35773634, -1.49380731],
#        [ 1.02287015,  0.59250739,  1.07057847,  1.13074433],
#        [-1.53430523,  0.11532023, -1.35773634, -1.36257972],
#        [-0.07306215, -0.60046051,  0.72367636,  1.52442707],
#        [ 0.41401887, -0.36186693,  0.2611402 ,  0.08092368],
#        [-1.16899446, -1.55483483, -0.31702999, -0.31275907],
#        [ 0.90109989, -0.12327335,  0.31895722,  0.21215126],
#        [-1.53430523,  1.30828813, -1.64682143, -1.36257972],
#        [-0.56014318,  0.83110097, -1.2421023 , -1.36257972],
#        [-0.31660267, -0.60046051,  0.60804232,  0.99951675],
#        [ 0.90109989, -0.36186693,  0.43459126,  0.08092368],
#        [ 0.17047836, -0.36186693,  0.37677424,  0.34337884],
#        [-0.68191343,  1.54688171, -1.35773634, -1.36257972],
#        [ 0.41401887,  0.83110097,  0.89712742,  1.39319949],
#        [-0.43837292,  2.73984961, -1.41555336, -1.36257972],
#        [-0.19483241, -0.60046051,  0.14550617,  0.08092368],
#        [ 2.24057271, -0.12327335,  1.30184655,  1.39319949],
#        [-0.43837292, -1.07764767,  0.31895722, -0.05030391],
#        [-0.19483241,  1.78547529, -1.2421023 , -1.23135214],
#        [ 0.77932964, -0.12327335,  0.78149338,  0.99951675],
#        [-1.77784574, -0.12327335, -1.47337037, -1.36257972],
#        [ 1.63172143, -0.12327335,  1.12839549,  0.47460642],
#        [-0.07306215, -0.83905409,  0.14550617, -0.31275907],
#        [-0.92545395,  1.78547529, -1.29991932, -1.36257972],
#        [-0.19483241, -0.12327335,  0.20332318, -0.05030391],
#        [-1.29076471,  0.11532023, -1.29991932, -1.36257972],
#        [ 1.02287015, -0.12327335,  0.78149338,  1.39319949],
#        [-1.53430523,  0.83110097, -1.41555336, -1.23135214],
#        [ 1.38818092,  0.35391381,  0.49240828,  0.21215126],
#        [ 0.65755938, -0.36186693,  0.2611402 ,  0.08092368],
#        [ 1.75349169, -0.36186693,  1.41748059,  0.73706158],
#        [ 2.48411322,  1.78547529,  1.47529761,  0.99951675],
#        [-0.56014318,  2.02406887, -1.2421023 , -1.10012456],
#        [-1.0472242 ,  0.83110097, -1.35773634, -1.36257972],
#        [-1.29076471,  0.83110097, -1.29991932, -1.36257972],
#        [ 0.53578913, -0.36186693,  1.01276145,  0.73706158],
#        [-0.07306215,  2.26266245, -1.53118739, -1.36257972],
#        [-0.92545395,  0.83110097, -1.35773634, -1.36257972],
#        [ 1.26641066,  0.11532023,  0.60804232,  0.34337884],
#        [-0.19483241, -0.60046051,  0.37677424,  0.08092368],
#        [ 0.65755938, -0.60046051,  1.01276145,  1.26197191],
#        [ 1.02287015,  0.59250739,  1.07057847,  1.65565466],
#        [ 0.65755938, -0.60046051,  1.01276145,  1.13074433],
#        [-1.29076471,  0.83110097, -1.12646826, -1.36257972],
#        [-1.41253497,  0.35391381, -1.47337037, -1.36257972],
#        [-0.07306215, -0.83905409,  0.72367636,  0.86828917],
#        [ 1.26641066,  0.11532023,  0.89712742,  1.13074433],
#        [-0.31660267, -0.12327335,  0.14550617,  0.08092368],
#        [-1.41253497,  0.35391381, -1.29991932, -1.36257972],
#        [-0.31660267, -0.83905409,  0.20332318,  0.08092368],
#        [-1.53430523,  0.35391381, -1.41555336, -1.36257972],
#        [ 0.29224861, -0.60046051,  0.08768915,  0.08092368],
#        [-1.0472242 , -2.50920915, -0.20139595, -0.31275907],
#        [ 0.53578913, -0.60046051,  0.72367636,  0.34337884],
#        [-0.56014318,  1.54688171, -1.35773634, -1.36257972],
#        [ 0.53578913, -0.83905409,  0.60804232,  0.73706158],
#        [ 0.65755938, -0.83905409,  0.8393104 ,  0.86828917],
#        [-0.56014318,  0.83110097, -1.35773634, -1.10012456],
#        [-1.0472242 ,  1.06969455, -1.47337037, -1.23135214],
#        [ 1.50995117, -0.12327335,  1.18621251,  1.13074433],
#        [-0.19483241, -1.31624125,  0.66585934,  0.99951675],
#        [-0.43837292, -1.55483483, -0.08576191, -0.31275907],
#        [-0.31660267, -0.36186693, -0.14357893,  0.08092368],
#        [-0.80368369,  1.06969455, -1.35773634, -1.36257972],
#        [ 0.53578913,  0.83110097,  1.01276145,  1.52442707],
#        [ 0.29224861, -0.12327335,  0.60804232,  0.73706158],
#        [ 1.14464041, -0.12327335,  0.95494443,  1.13074433],
#        [-0.92545395,  0.59250739, -1.2421023 , -0.96889698],
#        [-1.0472242 , -1.79342841, -0.31702999, -0.31275907],
#        [ 0.41401887, -2.03202199,  0.37677424,  0.34337884],
#        [ 1.02287015,  0.11532023,  0.31895722,  0.21215126]])

# %%
X_test = standardScaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.0487081 , -0.12327335,  0.20332318,  0.34337884],
#        [-1.0472242 ,  0.59250739, -1.41555336, -1.36257972],
#        [ 1.02287015,  0.11532023,  0.49240828,  0.34337884],
#        [-0.43837292,  1.06969455, -1.47337037, -1.36257972],
#        [-1.0472242 ,  0.35391381, -1.53118739, -1.36257972],
#        [-0.56014318,  2.02406887, -1.47337037, -1.10012456],
#        [-0.19483241,  3.21703677, -1.35773634, -1.10012456],
#        [ 0.65755938,  0.11532023,  0.95494443,  0.73706158],
#        [-1.0472242 ,  0.83110097, -1.29991932, -1.10012456],
#        [-1.16899446,  1.30828813, -1.41555336, -1.49380731],
#        [-1.16899446,  0.11532023, -1.35773634, -1.36257972],
#        [-1.16899446, -0.12327335, -1.41555336, -1.36257972],
#        [-0.07306215, -0.83905409,  0.02987213, -0.05030391],
#        [ 2.11880246, -0.12327335,  1.59093165,  1.13074433],
#        [ 0.17047836, -2.03202199,  0.66585934,  0.34337884],
#        [-0.92545395,  1.78547529, -1.35773634, -1.23135214],
#        [ 0.65755938,  0.35391381,  0.37677424,  0.34337884],
#        [-1.77784574,  0.35391381, -1.47337037, -1.36257972],
#        [-1.29076471, -0.12327335, -1.41555336, -1.49380731],
#        [-0.92545395,  1.54688171, -1.35773634, -1.10012456],
#        [ 0.53578913,  0.59250739,  0.49240828,  0.47460642],
#        [ 0.53578913, -1.79342841,  0.31895722,  0.08092368],
#        [ 0.53578913, -1.31624125,  0.66585934,  0.86828917],
#        [ 1.14464041, -0.60046051,  0.5502253 ,  0.21215126],
#        [-0.07306215, -0.83905409,  0.72367636,  0.86828917],
#        [-0.43837292, -1.31624125,  0.08768915,  0.08092368],
#        [ 2.24057271, -0.60046051,  1.64874867,  0.99951675],
#        [ 1.26641066,  0.11532023,  0.72367636,  1.39319949],
#        [ 0.53578913, -1.31624125,  0.60804232,  0.34337884],
#        [-1.16899446, -1.31624125,  0.37677424,  0.605834  ]])

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_clf = KNeighborsClassifier(n_neighbors=3)

# %%
knn_clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
knn_clf.score(X_test, y_test)
# Out:
# 0.9
